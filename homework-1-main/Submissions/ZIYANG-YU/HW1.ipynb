# %% [markdown]
# **Hello**
# *hello*

# %% [markdown]
# hello

# %% [markdown]
# ![](4.jpeg)

# %% [markdown]
# ## About this project
#
# This notebook demonstrates basic usage of Jupyter Notebook, including
# Markdown formatting and displaying local images.
#
# The content is based on a popular Chinese open-source project that
# collects various home-style cooking recipes.
